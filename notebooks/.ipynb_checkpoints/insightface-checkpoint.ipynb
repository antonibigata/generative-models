# %%
from insightface.app import FaceAnalysis

app = FaceAnalysis(name="buffalo_l", providers=["CUDAExecutionProvider", "CPUExecutionProvider"])

# %%
from torchvision.io import read_video

video, audio, info = read_video("/fsx/rs2517/data/HDTF/cropped_videos_original/WDA_ElijahCummings_000.mp4")
# Out:
# /data/home/antoni/miniconda3/envs/svd/lib/python3.10/site-packages/torchvision/io/video.py:161: UserWarning: The pts_unit 'pts' gives wrong results. Please use pts_unit 'sec'.
#   warnings.warn("The pts_unit 'pts' gives wrong results. Please use pts_unit 'sec'.")

# %%
face_align.norm_crop??
# Out:
# Signature: face_align.norm_crop(img, landmark, image_size=112, mode='arcface')
# Docstring: <no docstring>
# Source:
# def norm_crop(img, landmark, image_size=112, mode='arcface'):
#     M = estimate_norm(landmark, image_size, mode)
#     warped = cv2.warpAffine(img, M, (image_size, image_size), borderValue=0.0)
#     return warped
# File:      ~/miniconda3/envs/svd/lib/python3.10/site-packages/insightface/utils/face_align.py
# Type:      function

# %%
video.shape
# Out:
# torch.Size([6375, 772, 772, 3])

# %% [raw]
# from PIL import Image
# Image.fromarray(face_roi).resize((224, 224))

# %%
image = video[0]

app.prepare(ctx_id=0, det_size=(320, 320))

import time
from insightface.utils import face_align

start = time.time()
for i in range(10):
    for i in range(10):
        image = video[i].numpy()
        faces = app.get(image)
        faceid_embeds = torch.from_numpy(faces[0].normed_embedding).unsqueeze(0)
print(faceid_embeds.shape)
        # face_roi = face_align.norm_crop(image,faces[0]['kps'],112)
print("Duration :", (time.time() - start)/10)
# Out:
# set det-size: (320, 320)
# warning: det_size is already set in detection model, ignore
# torch.Size([1, 512])
# Duration : 0.19548144340515136

# %%
from facenet_pytorch import MTCNN, InceptionResnetV1

import torch

# If required, create a face detection pipeline using MTCNN:
mtcnn = MTCNN(image_size=160, margin=20, min_face_size=20, post_process=False, device="cuda")  # Keep everything as default
resnet = InceptionResnetV1(pretrained='vggface2').eval().to("cuda")

# Get cropped and prewhitened image tensor
with torch.no_grad():
    start = time.time()
    for i in range(10):
        img_cropped = mtcnn(video[:10].cuda())
        img_cropped = torch.stack(img_cropped)
        img_embedding = resnet(img_cropped.cuda())
print(img_embedding.shape)
print("Duration :", (time.time() - start)/10)
img = Image.fromarray(((img_cropped[0].permute(1,2,0))).clip(0,255).numpy().astype("uint8"))
img
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 13
#      11 start = time.time()
#      12 for i in range(10):
# ---> 13     img_cropped = mtcnn(video[:10].cuda())
#      14     img_cropped = torch.stack(img_cropped)
#      15     img_embedding = resnet(img_cropped.cuda())
#
# File ~/miniconda3/envs/svd/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/svd/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/miniconda3/envs/svd/lib/python3.10/site-packages/facenet_pytorch/models/mtcnn.py:265, in MTCNN.forward(self, img, save_path, return_prob)
#     261     batch_boxes, batch_probs, batch_points = self.select_boxes(
#     262         batch_boxes, batch_probs, batch_points, img, method=self.selection_method
#     263     )
#     264 # Extract faces
# --> 265 faces = self.extract(img, batch_boxes, save_path)
#     267 if return_prob:
#     268     return faces, batch_probs
#
# File ~/miniconda3/envs/svd/lib/python3.10/site-packages/facenet_pytorch/models/mtcnn.py:490, in MTCNN.extract(self, img, batch_boxes, save_path)
#     487     save_name, ext = os.path.splitext(path_im)
#     488     face_path = save_name + '_' + str(i + 1) + ext
# --> 490 face = extract_face(im, box, self.image_size, self.margin, face_path)
#     491 if self.post_process:
#     492     face = fixed_image_standardization(face)
#
# File ~/miniconda3/envs/svd/lib/python3.10/site-packages/facenet_pytorch/models/utils/detect_face.py:376, in extract_face(img, box, image_size, margin, save_path)
#     373     os.makedirs(os.path.dirname(save_path) + "/", exist_ok=True)
#     374     save_img(face, save_path)
# --> 376 face = F.to_tensor(np.float32(face))
#     378 return face
#
# File ~/miniconda3/envs/svd/lib/python3.10/site-packages/torch/_tensor.py:1032, in Tensor.__array__(self, dtype)
#    1030     return self.numpy()
#    1031 else:
# -> 1032     return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.

# %%
img_cropped[0].min(), img_cropped[0].max()
# Out:
# (tensor(-0.9961), tensor(0.9961))

# %%
image_encoder_path = "/data/home/antoni/code/generative-models/checkpoints/image_encoder"

from transformers import CLIPImageProcessor, CLIPVisionModelWithProjection

image_encoder = CLIPVisionModelWithProjection.from_pretrained(image_encoder_path).to(
            "cuda"
        )
clip_image_processor = CLIPImageProcessor()

# %%
from PIL import Image
Image.fromarray(face_roi).resize((224, 224))
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
clip_image = clip_image_processor(images=image.numpy()[None, ...], return_tensors="pt").pixel_values
clip_image = clip_image.to("cuda")
clip_image_embeds = image_encoder(clip_image, output_hidden_states=True).hidden_states[-1]

# %%
class ImageProjModel(torch.nn.Module):
    """Projection Model"""

    def __init__(self, cross_attention_dim=1024, clip_embeddings_dim=1024, clip_extra_context_tokens=4):
        super().__init__()

        self.generator = None
        self.cross_attention_dim = cross_attention_dim
        self.clip_extra_context_tokens = clip_extra_context_tokens
        self.proj = torch.nn.Linear(clip_embeddings_dim, self.clip_extra_context_tokens * cross_attention_dim)
        self.norm = torch.nn.LayerNorm(cross_attention_dim)

    def forward(self, image_embeds):
        embeds = image_embeds
        clip_extra_context_tokens = self.proj(embeds).reshape(
            -1, self.clip_extra_context_tokens, self.cross_attention_dim
        )
        clip_extra_context_tokens = self.norm(clip_extra_context_tokens)
        return clip_extra_context_tokens

image_proj_model = ImageProjModel(
        cross_attention_dim=self.pipe.unet.config.cross_attention_dim,
        clip_embeddings_dim=self.image_encoder.config.projection_dim,
        clip_extra_context_tokens=self.num_tokens,
    ).to(self.device, dtype=self.torch_type)

state_dict = torch.load("/data/home/antoni/code/ID-Animator/ID-Animator/animator.ckpt", map_location="cpu")
if 'state_dict' in state_dict:
    state_dict = state_dict['state_dict']
    image_proj_dict={}
    face_adapter_proj={}
    for k,v in state_dict.items():
        if k.startswith("module.image_proj_model"):
            image_proj_dict[k.replace("module.image_proj_model.", "")] = state_dict[k]
        elif k.startswith("module.adapter_modules."):
            face_adapter_proj[k.replace("module.adapter_modules.", "")] = state_dict[k]
        elif k.startswith("image_proj_model"):
            image_proj_dict[k.replace("image_proj_model.", "")] = state_dict[k]
        elif k.startswith("adapter_modules."):
            face_adapter_proj[k.replace("adapter_modules.", "")] = state_dict[k]
        else:
            print("ERROR!")
            return
    state_dict = {}
    state_dict['image_proj'] = image_proj_dict
    state_dict["face_adapter"] = face_adapter_proj
image_proj_model.load_state_dict(state_dict["image_proj"])
# Out:
# torch.Size([1, 1024])
