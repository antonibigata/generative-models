# %%
import moviepy.editor as mp

mp.VideoFileClip("/home/abigata/PhD/code/generative-models/outputs/simple_video_sample/svd/000032.mp4").ipython_display()
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
mp.VideoFileClip("/home/abigata/PhD/code/generative-models/outputs/simple_video_sample/svd/degraded.mp4").ipython_display()
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# t:   0%|          | 0/15 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>

# %%
mp.VideoFileClip("/home/abigata/PhD/Message_from_Barack_Obama.mp4").ipython_display()
# Out:
# Moviepy - Building video __temp__.mp4.
# MoviePy - Writing audio in __temp__TEMP_MPY_wvf_snd.mp3
# MoviePy - Done.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/abigata/PhD/code/generative-models/open_videos.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bremote-cvc1/home/abigata/PhD/code/generative-models/open_videos.ipynb#W1sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> mp.VideoFileClip("/home/abigata/PhD/Message_from_Barack_Obama.mp4").ipython_display()
#
# File ~/miniconda3/envs/tsr/lib/python3.9/site-packages/moviepy/video/io/html_tools.py:220, in ipython_display(clip, filetype, maxduration, t, fps, rd_kwargs, center, **html_kwargs)
#     217 if t is not None:
#     218     clip = clip.to_ImageClip(t)
# ...
